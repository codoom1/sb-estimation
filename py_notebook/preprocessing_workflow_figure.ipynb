# %% [markdown]
# # Preprocessing Workflow Figure
#
# This notebook regenerates the journal-style preprocessing workflow figure from the curated example data in `data/top_level_data`.

# %%
from pathlib import Path
from IPython.display import Image, display
import sys

project_root = Path.cwd().parent if Path.cwd().name == "py_notebook" else Path.cwd()
sys.path.insert(0, str(project_root / "scripts"))

from make_preprocessing_workflow_figure import build_figure

png_path, pdf_path = build_figure()
print(png_path)
print(pdf_path)
# Out:
# /Users/christopherodoom/Desktop/PhD_program/Research_Work/pctSitting_research/figures/wrist_accelerometry_preprocessing_workflow.png
# /Users/christopherodoom/Desktop/PhD_program/Research_Work/pctSitting_research/figures/wrist_accelerometry_preprocessing_workflow.pdf

# %%
display(Image(filename=str(png_path)))
